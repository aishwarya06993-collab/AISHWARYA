# %% [markdown]
# Today, I focused on understanding Unsupervised Learning concepts.
# I studied the K-Means clustering algorithm in detail.
# I learned how clustering works without predefined labels.
# I analyzed the role of centroids in forming clusters.
# I understood how Euclidean distance is used to assign data points.
# I performed data preprocessing and feature scaling.
# I observed the importance of StandardScaler for distance-based models.
# I implemented K-Means using scikit-learn.
# I experimented with different values of K (number of clusters).
# I applied the Elbow Method to find the optimal K value.
# I analyzed inertia (WCSS) to evaluate cluster compactness.
# I faced difficulty identifying a clear elbow in one dataset.
# I learned that K-Means assumes spherical clusters.
# I understood the impact of noise and data shape on clustering.
# I explored the issue of random centroid initialization.
# I used k-means++ to improve centroid placement.
# I visualized clusters and centroids using Matplotlib and Seaborn.
# I interpreted the hidden patterns discovered by the model.
# This task improved my understanding of unsupervised learning workflows.
# Overall, today’s work strengthened my practical machine learning skills.
