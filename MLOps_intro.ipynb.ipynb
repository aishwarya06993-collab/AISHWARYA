# %% [markdown]
# Work Summary (5 lines)
# Studied the concept of MLOps and its role in managing machine learning models in production.
# Understood why MLOps is essential for bridging the gap between development and deployment.
# Compared the Traditional ML Lifecycle with the MLOps Lifecycle.
# Analyzed additional stages introduced by MLOps such as monitoring and retraining.
# Reviewed how MLOps ensures scalability, reliability, and long-term model performance.
#
# Learning Outcomes (5 lines)
# Gained a clear understanding of what MLOps is and why it is used.
# Learned the limitations of the traditional ML lifecycle.
# Understood the complete end-to-end MLOps lifecycle stages.
# Learned how CI/CD concepts are applied in machine learning workflows.
# Developed awareness of maintaining and monitoring models after deployment.
#
# Blockages / Challenges (5 lines)
# Initial difficulty in understanding how MLOps differs from traditional ML workflows.
# Limited practical exposure to real-world MLOps tools and pipelines.
# Confusion between data validation and model validation concepts.
# Lack of hands-on experience with monitoring and retraining processes.
# Understanding CI/CD integration with ML models required additional clarification.
