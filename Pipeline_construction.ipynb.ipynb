# %% [markdown]
# Work Summary
# Worked on building ML pipelines using Scikit-Learn for efficient workflows.
# Combined preprocessing and modeling into a single structured pipeline.
# Used ColumnTransformer to handle numerical and categorical data together.
# Ensured consistent transformations and avoided data leakage issues.
#
# Learning
# Learned the concept of treating a pipeline as a single final model object.
# Understood how to apply scaling and encoding in a structured way.
# Gained knowledge about preventing data leakage during training.
# Explored reproducibility and automation in ML workflows.
#
# Outcomes
# Can build end-to-end pipelines for machine learning tasks.
# Improved ability to handle mixed datasets efficiently.
# Better understanding of model deployment readiness.
# Able to ensure consistency between training and testing processes.
#
# Blockages
# Faced issues with unknown categories during testing.
# Difficulty in debugging pipeline steps due to abstraction.
# Errors due to mismatch in column names between datasets.
# Needed extra effort to understand pipeline structure and parameters.
