# %% [markdown]
# Work Summary (Day 2 – Hackathon: Online Grocery Shopping Project)
# Today focused on preparing and delivering the presentation for our online grocery shopping project. I worked on organizing the content clearly, including problem statement, proposed solution, and key features. We highlighted how the platform improves convenience, saves time, and ensures better product availability. I also contributed to designing slides and explaining the workflow of the application. During the presentation, I explained user interaction and basic system functionality. Overall, the day was centered on communicating our idea effectively to others.
#
#
# Learning Outcomes
# I learned how to present a technical idea in a simple and understandable way. This helped me improve my communication and public speaking skills. I also understood the importance of structuring content logically in a presentation. Working with the team taught me collaboration and time management. I gained better clarity about our project’s real-world impact and usability. Additionally, I learned how to handle questions and feedback confidently.
#
#
# Blockages / Challenges
# One challenge was managing time while preparing the presentation within limited hours. There were some difficulties in clearly explaining technical aspects in simple terms. Coordination among team members was sometimes slightly confusing. I also felt a bit nervous while presenting in front of others. Technical issues like slide adjustments and formatting took extra time. Lastly, answering unexpected questions required quick thinking, which was a bit challenging.
